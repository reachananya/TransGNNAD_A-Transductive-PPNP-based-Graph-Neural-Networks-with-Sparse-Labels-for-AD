# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install numpy scikit-learn
# !pip install -q torch_geometric
# !pip install -q class_resolver
# !pip3 install pymatting
# !pip install opencv-python
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.6 MB/s eta 0:00:00
# Collecting pymatting
#   Downloading pymatting-1.1.14-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pymatting) (2.0.2)
# Requirement already satisfied: pillow>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from pymatting) (11.3.0)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.11/dist-packages (from pymatting) (0.60.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from pymatting) (1.16.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba!=0.49.0->pymatting) (0.43.0)
# Downloading pymatting-1.1.14-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: pymatting
# Successfully installed pymatting-1.1.14
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, log_loss
from sklearn.model_selection import StratifiedShuffleSplit
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
# Load CN and AD feature data
cn_path = "/content/drive/MyDrive/TejaswiAbburi_va797/Dataset/ISBI_ADNI_CN_dataset/Processed_histogram_features_CN/Histogram_feature_CN_FA_20bin.npy"
ad_path = "/content/drive/MyDrive/TejaswiAbburi_va797/Dataset/ISBI_ADNI_AD_dataset/Processed_histogram_features_AD/Histogram_feature_AD_FA_20bin.npy"

cn_data = np.load(cn_path, allow_pickle=True).item()
ad_data = np.load(ad_path, allow_pickle=True).item()

# %%
X_cn = np.array(list(cn_data.values()))
X_ad = np.array(list(ad_data.values()))

y_cn = np.zeros(X_cn.shape[0])   # CN = 0
y_ad = np.ones(X_ad.shape[0])    # AD = 1

# %%
# Combine data
X = np.vstack((X_cn, X_ad))
y = np.hstack((y_cn, y_ad))

np.random.seed(42)
perm = np.random.permutation(X.shape[0])
X = X[perm]
y = y[perm]
# Standardize
scaler = StandardScaler()
X = scaler.fit_transform(X)

# 20 Stratified Shuffle Splits
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

# Storage for metrics
accuracies, precisions, recalls, f1_scores, losses = [], [], [], [], []

# %%
all_y_true = []
all_y_proba = []
all_fpr = []
all_tpr = []
all_auc = []
# Cross-validation loop
for fold, (train_idx, test_idx) in enumerate(sss.split(X, y)):
    print(f"\nTraining fold {fold + 1}")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # MLP model (tuned for performance)
    mlp = MLPClassifier(hidden_layer_sizes=(512,),
                        activation='relu', solver='adam',
                        alpha=1e-3, max_iter=1000, random_state=42)

    mlp.fit(X_train, y_train)

    y_pred = mlp.predict(X_test)
    y_pred_proba = mlp.predict_proba(X_test)[:, 1]

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    loss = log_loss(y_test, y_pred_proba)
    auc_score = roc_auc_score(y_test, y_pred_proba)

    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)
    losses.append(loss)
    all_y_true.extend(y_test)
    all_y_proba.extend(y_pred_proba)

    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    all_fpr.append(fpr)
    all_tpr.append(tpr)
    all_auc.append(auc_score)

    print(f"Accuracy: {accuracy:.4f} | Precision: {precision:.4f} | Recall: {recall:.4f} | F1: {f1:.4f} | Loss: {loss:.4f} | AUC: {auc_score:.4f}")

# Final average results
print("\nAverage Results across 20 folds:")
print(f"Accuracy: {np.mean(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f}")
print(f"Recall: {np.mean(recalls):.4f}")
print(f"F1 Score: {np.mean(f1_scores):.4f}")
print(f"Cross-Entropy Loss: {np.mean(losses):.4f}")
print(f"Average AUC: {np.mean(all_auc):.4f}")
# Out:
# Training fold 1
# Accuracy: 0.7387 | Precision: 0.6484 | Recall: 0.7468 | F1: 0.6941 | Loss: 0.6916 | AUC: 0.7744
#
# Training fold 2
# Accuracy: 0.6683 | Precision: 0.5890 | Recall: 0.5443 | F1: 0.5658 | Loss: 0.7752 | AUC: 0.7222
#
# Training fold 3
# Accuracy: 0.7286 | Precision: 0.6374 | Recall: 0.7342 | F1: 0.6824 | Loss: 0.7093 | AUC: 0.7497
#
# Training fold 4
# Accuracy: 0.7136 | Precision: 0.6410 | Recall: 0.6329 | F1: 0.6369 | Loss: 0.6400 | AUC: 0.7594
#
# Training fold 5
# Accuracy: 0.6231 | Precision: 0.5227 | Recall: 0.5823 | F1: 0.5509 | Loss: 0.7680 | AUC: 0.6668
#
# Training fold 6
# Accuracy: 0.6734 | Precision: 0.5778 | Recall: 0.6582 | F1: 0.6154 | Loss: 0.9148 | AUC: 0.7503
#
# Training fold 7
# Accuracy: 0.7035 | Precision: 0.6163 | Recall: 0.6709 | F1: 0.6424 | Loss: 0.7290 | AUC: 0.7618
#
# Training fold 8
# Accuracy: 0.6533 | Precision: 0.5694 | Recall: 0.5190 | F1: 0.5430 | Loss: 0.7986 | AUC: 0.6834
#
# Training fold 9
# Accuracy: 0.4673 | Precision: 0.3516 | Recall: 0.4051 | F1: 0.3765 | Loss: 1.2418 | AUC: 0.4666
#
# Training fold 10
# Accuracy: 0.7136 | Precision: 0.6447 | Recall: 0.6203 | F1: 0.6323 | Loss: 0.6558 | AUC: 0.7453
#
# Training fold 11
# Accuracy: 0.6131 | Precision: 0.5114 | Recall: 0.5696 | F1: 0.5389 | Loss: 0.7982 | AUC: 0.6768
#
# Training fold 12
# Accuracy: 0.6935 | Precision: 0.6184 | Recall: 0.5949 | F1: 0.6065 | Loss: 0.7900 | AUC: 0.7278
#
# Training fold 13
# Accuracy: 0.6533 | Precision: 0.5521 | Recall: 0.6709 | F1: 0.6057 | Loss: 0.7342 | AUC: 0.7467
#
# Training fold 14
# Accuracy: 0.7085 | Precision: 0.6265 | Recall: 0.6582 | F1: 0.6420 | Loss: 0.7205 | AUC: 0.7744
#
# Training fold 15
# Accuracy: 0.6332 | Precision: 0.5366 | Recall: 0.5570 | F1: 0.5466 | Loss: 0.8970 | AUC: 0.6651
#
# Training fold 16
# Accuracy: 0.7337 | Precision: 0.7167 | Recall: 0.5443 | F1: 0.6187 | Loss: 0.6480 | AUC: 0.7449
#
# Training fold 17
# Accuracy: 0.6935 | Precision: 0.6023 | Recall: 0.6709 | F1: 0.6347 | Loss: 0.7708 | AUC: 0.7618
#
# Training fold 18
# Accuracy: 0.6583 | Precision: 0.5647 | Recall: 0.6076 | F1: 0.5854 | Loss: 0.7197 | AUC: 0.7297
#
# Training fold 19
# Accuracy: 0.7186 | Precision: 0.6386 | Recall: 0.6709 | F1: 0.6543 | Loss: 0.6963 | AUC: 0.7659
#
# Training fold 20
# Accuracy: 0.6834 | Precision: 0.5976 | Recall: 0.6203 | F1: 0.6087 | Loss: 0.7208 | AUC: 0.7450
#
# Average Results across 20 folds:
# Accuracy: 0.6736
# Precision: 0.5882
# Recall: 0.6139
# F1 Score: 0.5991
# Cross-Entropy Loss: 0.7710
# Average AUC: 0.7209

# %%
plt.figure(figsize=(8, 6))

for i in range(len(all_fpr)):
    plt.plot(all_fpr[i], all_tpr[i], alpha=0.3, label=f"Fold {i+1} AUC = {all_auc[i]:.2f}")

# Average ROC Curve
fpr_avg, tpr_avg, _ = roc_curve(all_y_true, all_y_proba)
auc_avg = roc_auc_score(all_y_true, all_y_proba)
plt.plot(fpr_avg, tpr_avg, color='blue', lw=2, label=f"Mean ROC (AUC = {auc_avg:.2f})")

# Diagonal line
plt.plot([0, 1], [0, 1], 'k--', label="Chance")
plt.xlabel("False Positive Rate", fontsize=16)
plt.ylabel("True Positive Rate", fontsize=16)
plt.title("ROC Curve Across 20 Folds (MLP)", fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc="lower right", fontsize=9)
plt.grid(True)
