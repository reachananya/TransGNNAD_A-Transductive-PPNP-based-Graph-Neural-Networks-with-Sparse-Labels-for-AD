# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install numpy scikit-learn
# !pip install -q torch_geometric
# !pip install -q class_resolver
# !pip3 install pymatting
# !pip install opencv-python
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.1 MB/s eta 0:00:00
# Collecting pymatting
#   Downloading pymatting-1.1.14-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pymatting) (2.0.2)
# Requirement already satisfied: pillow>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from pymatting) (11.3.0)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.11/dist-packages (from pymatting) (0.60.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from pymatting) (1.16.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba!=0.49.0->pymatting) (0.43.0)
# Downloading pymatting-1.1.14-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: pymatting
# Successfully installed pymatting-1.1.14
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, log_loss
from sklearn.model_selection import StratifiedShuffleSplit
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
# Load CN and MCI feature data
cn_path = "/content/drive/MyDrive/TejaswiAbburi_va797/Dataset/ISBI_ADNI_CN_dataset/Processed_histogram_features_CN/Histogram_feature_CN_FA_20bin.npy"
mci_path = "/content/drive/MyDrive/TejaswiAbburi_va797/Dataset/ISBI_ADNI_MCI_dataset/Processed_histogram_features_MCI/Histogram_feature_MCI_FA_20bin.npy"

cn_data = np.load(cn_path, allow_pickle=True).item()
mci_data = np.load(mci_path, allow_pickle=True).item()

# %%
X_cn = np.array(list(cn_data.values()))
X_mci = np.array(list(mci_data.values()))

y_cn = np.zeros(X_cn.shape[0])   # CN = 0
y_mci = np.ones(X_mci.shape[0])  # MCI = 1

# Combine data
X = np.vstack((X_cn, X_mci))
y = np.hstack((y_cn, y_mci))

# %%
np.random.seed(42)
perm = np.random.permutation(X.shape[0])
X = X[perm]
y = y[perm]

# %%
# Standardize
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# 20 Stratified Shuffle Splits
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.9, random_state=42)

# %%
# Storage for metrics
accuracies, precisions, recalls, f1_scores, losses = [], [], [], [], []

# %%
all_y_true = []
all_y_proba = []
all_fpr = []
all_tpr = []
all_auc = []
# Cross-validation loop
for fold, (train_idx, test_idx) in enumerate(sss.split(X, y)):
    print(f"\nTraining fold {fold + 1}")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # MLP model (tuned for performance)
    mlp = MLPClassifier(hidden_layer_sizes=(512,),
                        activation='relu', solver='adam',
                        alpha=1e-3, max_iter=1000, random_state=42)

    mlp.fit(X_train, y_train)

    y_pred = mlp.predict(X_test)
    y_pred_proba = mlp.predict_proba(X_test)[:, 1]

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    loss = log_loss(y_test, y_pred_proba)
    auc_score = roc_auc_score(y_test, y_pred_proba)

    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)
    losses.append(loss)
    all_y_true.extend(y_test)
    all_y_proba.extend(y_pred_proba)

    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    all_fpr.append(fpr)
    all_tpr.append(tpr)
    all_auc.append(auc_score)

    print(f"Accuracy: {accuracy:.4f} | Precision: {precision:.4f} | Recall: {recall:.4f} | F1: {f1:.4f} | Loss: {loss:.4f} | AUC: {auc_score:.4f}")

# Final average results
print("\nAverage Results across 20 folds:")
print(f"Accuracy: {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall: {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1 Score: {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"Cross-Entropy Loss: {np.mean(losses):.4f} ± {np.std(losses):.4f}")
print(f"Average AUC: {np.mean(all_auc):.4f} ± {np.std(all_auc):.4f}")
# Out:
# Training fold 1
# Accuracy: 0.7630 | Precision: 0.7829 | Recall: 0.7933 | F1: 0.7881 | Loss: 0.6589 | AUC: 0.8006
#
# Training fold 2
# Accuracy: 0.7370 | Precision: 0.7516 | Recall: 0.7867 | F1: 0.7687 | Loss: 0.6416 | AUC: 0.7808
#
# Training fold 3
# Accuracy: 0.7222 | Precision: 0.7389 | Recall: 0.7733 | F1: 0.7557 | Loss: 0.6661 | AUC: 0.7691
#
# Training fold 4
# Accuracy: 0.7444 | Precision: 0.7580 | Recall: 0.7933 | F1: 0.7752 | Loss: 0.6393 | AUC: 0.8194
#
# Training fold 5
# Accuracy: 0.7259 | Precision: 0.7346 | Recall: 0.7933 | F1: 0.7628 | Loss: 1.0539 | AUC: 0.7409
#
# Training fold 6
# Accuracy: 0.7185 | Precision: 0.7606 | Recall: 0.7200 | F1: 0.7397 | Loss: 0.7664 | AUC: 0.7662
#
# Training fold 7
# Accuracy: 0.7444 | Precision: 0.7832 | Recall: 0.7467 | F1: 0.7645 | Loss: 0.7359 | AUC: 0.7943
#
# Training fold 8
# Accuracy: 0.7815 | Precision: 0.7542 | Recall: 0.9000 | F1: 0.8207 | Loss: 0.6055 | AUC: 0.8113
#
# Training fold 9
# Accuracy: 0.6667 | Precision: 0.7174 | Recall: 0.6600 | F1: 0.6875 | Loss: 0.8871 | AUC: 0.7335
#
# Training fold 10
# Accuracy: 0.7259 | Precision: 0.7289 | Recall: 0.8067 | F1: 0.7658 | Loss: 0.7266 | AUC: 0.7847
#
# Training fold 11
# Accuracy: 0.7333 | Precision: 0.7635 | Recall: 0.7533 | F1: 0.7584 | Loss: 0.6774 | AUC: 0.7927
#
# Training fold 12
# Accuracy: 0.7148 | Precision: 0.7239 | Recall: 0.7867 | F1: 0.7540 | Loss: 0.6916 | AUC: 0.7792
#
# Training fold 13
# Accuracy: 0.7407 | Precision: 0.7381 | Recall: 0.8267 | F1: 0.7799 | Loss: 0.7457 | AUC: 0.7843
#
# Training fold 14
# Accuracy: 0.6852 | Precision: 0.7273 | Recall: 0.6933 | F1: 0.7099 | Loss: 0.8497 | AUC: 0.7465
#
# Training fold 15
# Accuracy: 0.7630 | Precision: 0.7722 | Recall: 0.8133 | F1: 0.7922 | Loss: 0.6139 | AUC: 0.8241
#
# Training fold 16
# Accuracy: 0.7889 | Precision: 0.7888 | Recall: 0.8467 | F1: 0.8167 | Loss: 0.7273 | AUC: 0.7998
#
# Training fold 17
# Accuracy: 0.6926 | Precision: 0.7190 | Recall: 0.7333 | F1: 0.7261 | Loss: 0.7883 | AUC: 0.7539
#
# Training fold 18
# Accuracy: 0.7000 | Precision: 0.7197 | Recall: 0.7533 | F1: 0.7362 | Loss: 0.7356 | AUC: 0.7724
#
# Training fold 19
# Accuracy: 0.7296 | Precision: 0.7278 | Recall: 0.8200 | F1: 0.7712 | Loss: 0.8211 | AUC: 0.7521
#
# Training fold 20
# Accuracy: 0.6889 | Precision: 0.6941 | Recall: 0.7867 | F1: 0.7375 | Loss: 0.7368 | AUC: 0.7501
#
# Average Results across 20 folds:
# Accuracy: 0.7283 ± 0.0311
# Precision: 0.7442 ± 0.0251
# Recall: 0.7793 ± 0.0526
# F1 Score: 0.7605 ± 0.0317
# Cross-Entropy Loss: 0.7384 ± 0.1035
# Average AUC: 0.7778 ± 0.0256

# %%
plt.figure(figsize=(8, 6))

for i in range(len(all_fpr)):
    plt.plot(all_fpr[i], all_tpr[i], alpha=0.3, label=f"Fold {i+1} AUC = {all_auc[i]:.2f}")

# Average ROC Curve
fpr_avg, tpr_avg, _ = roc_curve(all_y_true, all_y_proba)
auc_avg = roc_auc_score(all_y_true, all_y_proba)
plt.plot(fpr_avg, tpr_avg, color='blue', lw=2, label=f"Mean ROC (AUC = {auc_avg:.2f})")

# Diagonal line
plt.plot([0, 1], [0, 1], 'k--', label="Chance")
plt.xlabel("False Positive Rate", fontsize=16)
plt.ylabel("True Positive Rate", fontsize=16)
plt.title("ROC Curve Across 20 Folds (MLP)", fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc="lower right", fontsize=9)
plt.grid(True)
